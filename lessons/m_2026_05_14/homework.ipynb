# %%
print(123)
# Out:
# 123

# %%
a=int(35)
a
# Out:
# 35

# %%
type(a)
# Out:
# int

# %%
a=2
a
# Out:
# 2

# %%
s="123"
s
# Out:
# '123'

# %%
s=int("123")
s
# Out:
# 123

# %%
type(s)
# Out:
# int

# %%
s=int("123a")
s
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s=int("123a")
#       2 s
#
# ValueError: invalid literal for int() with base 10: '123a'

# %%
s+s
# Out:
# 246

# %%
s="123"
s+s
# Out:
# '123123'
