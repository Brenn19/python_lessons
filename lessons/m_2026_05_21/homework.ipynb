# %%
# Задача 1. Калькулятор целых чисел (int)
# ============================================
print("=== Задача 1. Калькулятор целых чисел ===")
# Ввод двух целых чисел
a = int(input("Введите первое целое число: "))
b = int(input("Введите второе целое число: "))

# Вычисление и вывод результатов
print(f"Сумма: {a + b}")
print(f"Разность: {a - b}")
print(f"Произведение: {a * b}")
print(f"Целочисленное деление: {a // b}")
print(f"Остаток от деления: {a % b}")
print(f"Степень: {a ** b}")
print("\n" + "="*40 + "\n")
# Out:
# === Задача 1. Калькулятор целых чисел ===
# Сумма: 8
# Разность: -2
# Произведение: 15
# Целочисленное деление: 0
# Остаток от деления: 3
# Степень: 243
#
# ...

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# Задача 1. Калькулятор целых чисел (int)
# =======================================
print("=== Задача 1. Калькулятор целых чисел ===")
# Ввод двух целых чисел
a = int(input("Введите первое целое число: "))
b = int(input("Введите второе целое число: "))

# Вычисление и вывод результатов
print(f"Сумма: {a+b}")
print(f"Разность: {a-b}")
print(f"Произведение: {a*b}")
print(f"Целочисленное деление: {a // b}")
print(f"Остаток от деления: {a % b}")
print(f"Степень: {a**b}")
print("\n" + "="*40 + "\n")
# Out:
# === Задача 1. Калькулятор целых чисел ===
# Сумма: 64
# Разность: 24
# Произведение: 880
# Целочисленное деление: 2
# Остаток от деления: 4
# Степень: 739696442014594807059393047166976
#
# ...

# %%
"a" + "b"a
# Out:
# 'ab'

# %%
"a" *10
# Out:
# 'aaaaaaaaaa'

# %%
# ============================================
# Задача 2. Площадь круга и длина окружности (float)
# ============================================
print("=== Задача 2. Площадь круга и длина окружности ===")
# Ввод радиуса (вещественное число)
radius = float(input("Введите радиус окружности: "))
pi = 3.14159

area = pi * radius ** 2
circumference = 2 * pi * radius

# Округление до двух знаков
area = 1
print(f"Площадь круга: {area:.2f}")
print(f"Длина окружности: {circumference:.0f}")
print("\n" + "="*40 + "\n")
# Out:
# === Задача 2. Площадь круга и длина окружности ===
# Площадь круга: 1.00
# Длина окружности: 25
#
# ...

# %%
# ============================================
# Задача 3. Анализ строки (str)
# ============================================
print("=== Задача 3. Анализ строки ===")
# Ввод произвольной строки
text = input("Введите произвольную строку: ")

# Вывод информации о строке
print(f"Длина строки: {len(text)}")
print(f"Первый символ: {text[0] if text else 'строка пуста'}")
print(f"Последний символ: {text[-1] if text else 'строка пуста'}")
print(f"В верхнем регистре: {text.upper()}")
print(f"Количество пробелов: {text.count(' ')}")
print("\n" + "="*40 + "\n")

# %%
"a".upper()

# %%
# Задача 1. Калькулятор целых чисел.and
# ========================================
print("=== Задача 1. Калькулятор целых чисел. ===")
# ввод двух целых чисел
a = int(input("Введите первое целое число: m"))
b = int(input("Введите второе целое число: "))

# Вычисление и вывод результатов
print(f"Сумма: {a+b}")
print(f"Разность: {a-b}")
print(f"Произведение: {a*b}")
print(f"Целочисленное деление: {a // b}")
print(F"Остаток от деления: {a % b}")
print(f"Степень: {a**b}")
print("\n" + "="*40 + "\n")
# Out:
# === Задача 1. Калькулятор целых чисел. ===
# Сумма: 12
# Разность: -2
# Произведение: 35
# Целочисленное деление: 0
# Остаток от деления: 5
# Степень: 78125
#
# ...

# %%
from decimal import Decimal

# %%
nums = [5, 5, 33]
print(nums)
type(nums)
# Out:
# [5, 5, 33]
# list

# %%
nums = [5, 99, True, "Hello", 6.9]
nums[0] = 50
nums[4] = 1

print(nums)
# Out:
# [50, 99, True, 'Hello', 1]

# %%
nums = [2, 5, 99, True, 5.33, [5, 7]]
nums[0] = 50
nums[4] = 1.01
print(nums[5])
# Out:
# [5, 7]

# %%
nums = [1, 44, 1.909, True, 44, 77, [4,[3, True]]]
print(nums[-1][1][1])
# Out:
# True

# %%
numbers = [0, False,1, 5, 2, 7, 1]
# numbers[3] = 100
numbers.append(100)
numbers.append(True)
numbers.insert(1, True)

numbers.extend((5, 6, 8))
# numbers.append([5, 6, 8])
numbers.sort(reverse=True)
print(numbers)
# Out:
# [100, 8, 7, 6, 5, 5, 2, True, 1, 1, True, 0, False]

# %%
numbers = [0, False,1, 5, 2, 7, 1]
deleted = numbers.pop()
print(deleted)
numbers
# Out:
# 1
# [0, False, 1, 5, 2, 7]

# %%
numbers = [0, False,1, 5, 2, 7, 1]
deleted = numbers.pop(-3)
print(deleted)
numbers
# Out:
# 2
# [0, False, 1, 5, 7, 1]

# %%
numbers = [0, False,1, 5, 2, 7, 1]
deleted = numbers.pop(-9)
print(deleted)
numbers
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 numbers = [0, False,1, 5, 2, 7, 1]
# ----> 2 deleted = numbers.pop(-9)
#       3 print(deleted)
#       4 numbers
#
# IndexError: pop index out of range

# %%
numbers = []
deleted = numbers.pop()
print(deleted)
numbers
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 numbers = []
# ----> 2 deleted = numbers.pop()
#       3 print(deleted)
#       4 numbers
#
# IndexError: pop from empty list

# %%
numbers = [0, False,5, 1, 5, 2, 7, 1]
deleted = numbers.remove(5)
print(deleted)
numbers
# Out:
# None
# [0, False, 1, 5, 2, 7, 1]

# %%
numbers.count(5)
# Out:
# 1

# %%
numbers = [0, False,5, 1, 5, 2, 7, 1]
len(numbers)
# Out:
# 8

# %%
numbers.__len__()
# Out:
# 8

# %%
f"Имя - {name}, Фамилия - {surname}, возраст - {age}"
# Out:
# 'Имя - Иван, Фамилия - Иванов, возраст - 35'

# %%
name = Иван
surname = Иванов
age = 35
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 name = Иван
#       2 surname = Иванов
#       3 age = 35
#
# NameError: name 'Иван' is not defined

# %%
name = Иван
surname = Иванов
age = 35
f"Имя - {name}, Фамилия - {surname}, Возраст - {age} "
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 name = Иван
#       2 surname = Иванов
#       3 age = 35
#       4 f"Имя - {name}, Фамилия - {surname}, Возраст - {age} "
#
# NameError: name 'Иван' is not defined

# %%
f"Имя - {name}, Фамилия - {surname}, возраст - {age}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 f"Имя - {name}, Фамилия - {surname}, возраст - {age}"
#
# NameError: name 'name' is not defined
